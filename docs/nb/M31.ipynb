# %% [markdown]
# # M31

# %%
# imports
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

import pandas

from astropy.coordinates import SkyCoord
from astropy import units

from scipy import interpolate
from scipy.stats import pearsonr, ks_2samp

from frb.halos import models

# %% [markdown]
# # Init

# %%
rstate = np.random.RandomState()

# %%
Nrandom=20000
zmax=1.
N_rvir=1.

# %%
sns.set_theme()
sns.set_style('whitegrid')
sns.set_context('talk')

# %% [markdown]
# ## DM$_{\rm cosmic}$ grid

# %%
grid_file = '/home/xavier/papers/FRB/Proposals/DM_CDF_grid.npz'

# %%
nsz = np.load(grid_file)
DM_grid = nsz['DM_grid']
zvals = nsz['zvals']
CDF_val = nsz['CDF_val']
f2D_cosmic = interpolate.RectBivariateSpline(CDF_val, zvals, DM_grid)

# %% [markdown]
# ## Pandas

# %%
df = pandas.DataFrame()

# %% [markdown]
# # FRB redshift

# %%
zFRB = rstate.uniform(0., zmax, Nrandom)

# %%
df['zFRB'] = zFRB

# %% [markdown]
# # Random DM$_{\rm cosmic}$

# %%
randnum = rstate.rand(Nrandom)
DM_cosmic = f2D_cosmic.ev(randnum, zFRB)

# %%
df['DM_cosmic'] = DM_cosmic

# %% [markdown]
# ## Plot

# %%
fig = plt.figure(figsize=(7,7))
sns.scatterplot(data=df, x='zFRB', y='DM_cosmic', s=3)
# Out:
# <AxesSubplot:xlabel='zFRB', ylabel='DM_cosmic'>

# %% [markdown]
# # Milky Way ISM/Halo scatter

# %%
# ISM+halo -- Assume +/- 15 pc cm^-3 uncertainty in NE2001 model
sig_ISM = rstate.uniform(-15., 15., Nrandom)

# %%
# Galaxy
DM_MW_halo = 50. # pc/cm^3

# %%
df['DM_MW_halo'] = DM_MW_halo
df['DM_ISM'] = sig_ISM

# %% [markdown]
# # DM$_{\rm host}$
#
# ## Should probably use the log-normal PDF eventually

# %%
# Host halo
DM_halo = np.maximum(rstate.normal(40., 20., Nrandom), 0.)  # pc/cm^3

# %%
df['DM_halo'] = DM_halo

# %% [markdown]
# # Random direction on the sky

# %%
# Random direction
ranl = rstate.uniform(0,360., Nrandom)  # deg
costheta = rstate.uniform(-1, 1, Nrandom)
ranb = np.arccos(costheta)*180./np.pi - 90. # deg
ran_coord = SkyCoord(b=ranb, l=ranl, frame='galactic', unit='deg')

# %%
np.min(ranb)
# Out:
# -89.38605710877127

# %% [markdown]
# # M31

# %% [markdown]
# ## Instantiate

# %%
# M31
m31 = models.M31()
m31
# Out:
# <M31: 00:42:44.3 +41:16:09, logM=12.180000, r200=302.769 kpc>

# %% [markdown]
# ## Interpolate DMs

# %%
Rmin = 10. # kpc -- Take a constant value within this impact parameter
Rvals = np.linspace(Rmin, N_rvir*m31.r200.value, 200) # For splining
DMvals = np.zeros_like(Rvals)
for kk, iRperp in enumerate(Rvals):
    DMvals[kk] = m31.Ne_Rperp(iRperp * units.kpc, rmax=N_rvir).to('pc/cm**3').value
fDM = interpolate.interp1d(Rvals, DMvals, kind='cubic')

# %% [markdown]
# ## Project

# %%
a=1
c=0
x0, y0 = m31.distance.to('kpc').value, 0. # kpc (Riess, A.G., Fliri, J., & Valls - Gabaud, D. 2012, ApJ, 745, 156)

sep = m31.coord.separation(ran_coord)

atan = np.arctan(sep.radian)
b = -1 * a / atan
Rperp = np.ones(Nrandom)*9e9 # kpc
ok = sep < 90.*units.deg
Rperp[ok] = np.abs(a * x0 + b[ok] * y0 + c) / np.sqrt(a ** 2 + b[ok] ** 2)  # kpc

# %% [markdown]
# ## DMs

# %%
DM_M31 = np.zeros(Nrandom)
in_ism = Rperp <= Rmin
in_halo = (Rperp < N_rvir*m31.r200.value) & (Rperp > Rmin)
out_halo = (Rperp > N_rvir*m31.r200.value)
DM_M31[in_ism] = np.max(DMvals)
DM_M31[in_halo] = fDM(Rperp[in_halo])

# %%
df['DM_M31'] = DM_M31
# Labels
lbls = np.array(['out']*Nrandom)
lbls[~out_halo] = 'in'
df['M31'] = lbls

# %%
# Sum em up
total_DMs = DM_cosmic + DM_halo + DM_M31 + sig_ISM + DM_MW_halo

# %%
df['total'] = total_DMs

# %% [markdown]
# # Compare

# %% [markdown]
# ## Histogram

# %%
_ = sns.displot(df, x='total', hue='M31', stat='density', common_norm=False, height=7., aspect=1.5)

# %% [markdown]
# ## CDF

# %%
ax = sns.ecdfplot(data=df, x='total', hue='M31')
ax.set_xlim(0., 1000.)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# ### KS

# %%
D_stat, P_KS = ks_2samp(total_DMs[out_halo], total_DMs[~out_halo])
P_KS
# Out:
# 0.0014638165676071375

# %%
np.mean(DM_M31[~out_halo])
# Out:
# 19.28540996974873

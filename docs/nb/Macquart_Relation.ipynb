# %% [markdown]
# # Macquart Relation

# %%
# imports
from importlib import reload 
import numpy as np

from frb import frb
from frb.figures import dm as dm_figs

# %%
# %matplotlib notebook

# %% [markdown]
# # Load up the FRBs

# %%
frbs = frb.list_of_frbs(require_z=True)

# %%
# Trim down
frbs = frbs[:-1]
frbs
# Out:
# [<FRB: FRB121102 J053158.7+330852.5 DM=558.1 pc / cm3 z=0.19273>,
#  <FRB: FRB180916 J015800.7502+654300.3152 DM=348.76 pc / cm3 z=0.0337>,
#  <FRB: FRB180924 J214425.255-405400.1 DM=362.16 pc / cm3 z=0.3212>,
#  <FRB: FRB181112 J214923.63-525815.33 DM=589.27 pc / cm3 z=0.4755>,
#  <FRB: FRB190102 J212939.76-792832.5 DM=364.545 pc / cm3 z=0.2912>,
#  <FRB: FRB190523 J134815.6+722811 DM=760.8 pc / cm3 z=0.66>,
#  <FRB: FRB190608 J221604.77-075353.7 DM=339.8 pc / cm3 z=0.1177805>,
#  <FRB: FRB190611 J212258.91-792351.3 DM=332.63 pc / cm3 z=0.3778>,
#  <FRB: FRB190711 J215740.68-802128.8 DM=587.9 pc / cm3 z=0.52172>,
#  <FRB: FRB190714 J121555.12-130115.7 DM=504.13 pc / cm3 z=0.2365>,
#  <FRB: FRB191001 J213324.373-544451.86 DM=507.9 pc / cm3 z=0.234>]

# %% [markdown]
# # Figure

# %%
reload(dm_figs)
dm_figs.fig_cosmic(frbs, gold_only=False, show_sigmaDM=True)
# Out:
# <img src="data:image/png;base64,..." width="799.65">
# /home/xavier/Projects/FRB/frb/figures/dm.py:288: RuntimeWarning: divide by zero encountered in power
#   sigma_DM = F * zeval**(-0.5) #* DM_cosmic.value
# DM_nuisance = 100.0
